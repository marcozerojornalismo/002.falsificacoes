# %%
import pandas as pd
import numpy as np
from numpy.random import randn
from scipy import stats
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
fals = pd.read_csv('002.falsificacao/falsificacao.csv')

# %%
fals.quantidade.value_counts()
# Out:
# 1        216
# 2        136
# 3        105
# 4         73
# 6         73
# 5         62
# 7         60
# 8         47
# 11        41
# 9         36
# 14        34
# 12        34
# 10        31
# 17        31
# 13        30
# 19        28
# 20        28
# 18        26
# 25        24
# 16        23
# 22        23
# 15        22
# 21        21
# 23        20
# 24        20
# 30        19
# 26        18
# 34        17
# 44        17
# 31        17
#         ...
# 786        1
# 2843       1
# 798        1
# 802        1
# 37668      1
# 818        1
# 822        1
# 2875       1
# 830        1
# 746        1
# 19175      1
# 6885       1
# 2735       1
# 25234      1
# 2711       1
# 2715       1
# 2723       1
# 6821       1
# 10923      1
# 686        1
# 1017       1
# 8922       1
# 694        1
# 698        1
# 6857       1
# 8558       1
# 718        1
# 722        1
# 726        1
# 2047       1
# Name: quantidade, Length: 1604, dtype: int64

# %%
falsestado = fals [ fals.estado == 'PARANÁ']
#falsestadoq = falsestado.quantidade
#falsestadoq.sum()
falsestado.tipo2.sum()
# Out:
# 5033

# %%
#1998
falsano1998 = fals [fals.ano == 1998]
falsano1998_1 = falsano1998 [falsano1998.tipo2 == 1]
falsano1998_5 = falsano1998 [falsano1998.tipo2 == 5]
falsano1998_10 = falsano1998 [falsano1998.tipo2 == 10]
falsano1998_20 = falsano1998 [falsano1998.tipo2 == 20]
falsano1998_50 = falsano1998 [falsano1998.tipo2 == 50]
falsano1998_100 = falsano1998 [falsano1998.tipo2 == 100]

print falsano1998_1.sum()
print falsano1998_5.sum()
print falsano1998_10.sum()
print falsano1998_20.sum()
print falsano1998_50.sum()
print falsano1998_100.sum()
# Out:
# ano           0.0
# estado        0.0
# tipo          0.0
# tipo2         0.0
# quantidade    0.0
# dtype: float64
# ano                                                        5994
# estado                                   AMAZONASCEARÁSÃO PAULO
# tipo          Cédulas - 1a. famíliaCédulas - 1a. famíliaCédu...
# tipo2                                                        15
# quantidade                                                   27
# dtype: object
# ano                                                       19980
# estado        AMAZONASCEARÁESPÍRITO SANTOGOIÁSMATO GROSSOMIN...
# tipo          Cédulas - 1a. famíliaCédulas - 1a. famíliaCédu...
# tipo2                                                       100
# quantidade                                                 2256
# dtype: object
# ano           0.0
# estado        0.0
# tipo          0.0
# tipo2         0.0
# quantidade    0.0
# dtype: float64
# ano                                                       19980
# ...

# %%
#1999
falsano1999 = fals [fals.ano == 1999]
falsano1999_1 = falsano1999 [falsano1999.tipo2 == 1]
falsano1999_5 = falsano1999 [falsano1999.tipo2 == 5]
falsano1999_10 = falsano1999 [falsano1999.tipo2 == 10]
falsano1999_20 = falsano1999 [falsano1999.tipo2 == 20]
falsano1999_50 = falsano1999 [falsano1999.tipo2 == 50]
falsano1999_100 = falsano1999 [falsano1999.tipo2 == 100]

print falsano1999_1.sum()
print falsano1999_5.sum()
print falsano1999_10.sum()
print falsano1999_20.sum()
print falsano1999_50.sum()
print falsano1999_100.sum()
# Out:
# ano                                                        7996
# estado                  MINAS GERAISPERNAMBUCORONDÔNIASÃO PAULO
# tipo          Cédulas - 1a. famíliaCédulas - 1a. famíliaCédu...
# tipo2                                                         4
# quantidade                                                   20
# dtype: object
# ano                                                       45977
# estado        ALAGOASAMAZONASBAHIACEARÁDISTRITO FEDERALESPÍR...
# tipo          Cédulas - 1a. famíliaCédulas - 1a. famíliaCédu...
# tipo2                                                       115
# quantidade                                                  848
# dtype: object
# ano                                                       53973
# estado        ACREALAGOASAMAPÁAMAZONASBAHIACEARÁDISTRITO FED...
# tipo          Cédulas - 1a. famíliaCédulas - 1a. famíliaCédu...
# tipo2                                                       270
# ...

# %%
#2000
falsano2000 = fals [fals.ano == 2000]
falsano2000_1 = falsano2000 [falsano2000.tipo2 == 1]
falsano2000_5 = falsano2000 [falsano2000.tipo2 == 5]
falsano2000_10 = falsano2000 [falsano2000.tipo2 == 10]
falsano2000_20 = falsano2000 [falsano2000.tipo2 == 20]
falsano2000_50 = falsano2000 [falsano2000.tipo2 == 50]
falsano2000_100 = falsano2000 [falsano2000.tipo2 == 100]

print falsano2000_1.sum()
print falsano2000_5.sum()
print falsano2000_10.sum()
print falsano2000_20.sum()
print falsano2000_50.sum()
print falsano2000_100.sum()
# Out:
# ano                                                       36000
# estado        ALAGOASBAHIACEARÁDISTRITO FEDERALESPÍRITO SANT...
# tipo          Cédulas - 1a. famíliaCédulas - 1a. famíliaCédu...
# tipo2                                                        18
# quantidade                                                  294
# dtype: object
# ano                                                       48000
# estado        ALAGOASAMAZONASBAHIACEARÁDISTRITO FEDERALESPÍR...
# tipo          Cédulas - 1a. famíliaCédulas - 1a. famíliaCédu...
# tipo2                                                       120
# quantidade                                                15914
# dtype: object
# ano                                                       64000
# estado        ACREALAGOASAMAPÁAMAZONASBAHIACEARÁDISTRITO FED...
# tipo          Cédulas - 1a. famíliaCédulas - 1a. famíliaCédu...
# tipo2                                                       320
# ...

# %%
#2001
falsano2001 = fals [fals.ano == 2001]
falsano2001_1 = falsano2001 [falsano2001.tipo2 == 1]
falsano2001_5 = falsano2001 [falsano2001.tipo2 == 5]
falsano2001_10 = falsano2001 [falsano2001.tipo2 == 10]
falsano2001_20 = falsano2001 [falsano2001.tipo2 == 20]
falsano2001_50 = falsano2001 [falsano2001.tipo2 == 50]
falsano2001_100 = falsano2001 [falsano2001.tipo2 == 100]

print falsano2001_1.sum()
print falsano2001_5.sum()
print falsano2001_10.sum()
print falsano2001_20.sum()
print falsano2001_50.sum()
print falsano2001_100.sum()
# Out:
# ano                                                       38019
# estado        ALAGOASAMAZONASBAHIACEARÁDISTRITO FEDERALESPÍR...
# tipo          Cédulas - 1a. famíliaCédulas - 1a. famíliaCédu...
# tipo2                                                        19
# quantidade                                                  336
# dtype: object
# ano                                                       50025
# estado        ACREALAGOASAMAPÁAMAZONASBAHIACEARÁDISTRITO FED...
# tipo          Cédulas - 1a. famíliaCédulas - 1a. famíliaCédu...
# tipo2                                                       125
# quantidade                                                28459
# dtype: object
# ano                                                       96048
# estado        ACREALAGOASALAGOASAMAPÁAMAZONASAMAZONASBAHIABA...
# tipo          Cédulas - 1a. famíliaCédulas - 1a. famíliaCédu...
# tipo2                                                       480
# ...

# %%
#2002
falsano2002 = fals [fals.ano == 2002]
falsano2002_1 = falsano2002 [falsano2002.tipo2 == 1]
falsano2002_5 = falsano2002 [falsano2002.tipo2 == 5]
falsano2002_10 = falsano2002 [falsano2002.tipo2 == 10]
falsano2002_20 = falsano2002 [falsano2002.tipo2 == 20]
falsano2002_50 = falsano2002 [falsano2002.tipo2 == 50]
falsano2002_100 = falsano2002 [falsano2002.tipo2 == 100]

print falsano2002_1.sum()
print falsano2002_5.sum()
print falsano2002_10.sum()
print falsano2002_20.sum()
print falsano2002_50.sum()
print falsano2002_100.sum()
# Out:
# ano                                                       32032
# estado        ALAGOASAMAZONASBAHIADISTRITO FEDERALGOIÁSMARAN...
# tipo          Cédulas - 1a. famíliaCédulas - 1a. famíliaCédu...
# tipo2                                                        16
# quantidade                                                  405
# dtype: object
# ano                                                       50050
# estado        ACREALAGOASAMAZONASBAHIACEARÁDISTRITO FEDERALE...
# tipo          Cédulas - 1a. famíliaCédulas - 1a. famíliaCédu...
# tipo2                                                       125
# quantidade                                                27200
# dtype: object
# ano                                                       92092
# estado        ACREALAGOASALAGOASAMAPÁAMAZONASAMAZONASBAHIACE...
# tipo          Cédulas - 1a. famíliaCédulas - 1a. famíliaCédu...
# tipo2                                                       460
# ...

# %%
#2003
falsano2003 = fals [fals.ano == 2003]
falsano2003_1 = falsano2003 [falsano2003.tipo2 == 1]
falsano2003_5 = falsano2003 [falsano2003.tipo2 == 5]
falsano2003_10 = falsano2003 [falsano2003.tipo2 == 10]
falsano2003_20 = falsano2003 [falsano2003.tipo2 == 20]
falsano2003_50 = falsano2003 [falsano2003.tipo2 == 50]
falsano2003_100 = falsano2003 [falsano2003.tipo2 == 100]

print falsano2003_1.sum()
print falsano2003_5.sum()
print falsano2003_10.sum()
print falsano2003_20.sum()
print falsano2003_50.sum()
print falsano2003_100.sum()
# Out:
# ano                                                       28042
# estado        BAHIACEARÁDISTRITO FEDERALESPÍRITO SANTOGOIÁSM...
# tipo          Cédulas - 1a. famíliaCédulas - 1a. famíliaCédu...
# tipo2                                                        14
# quantidade                                                  254
# dtype: object
# ano                                                       52078
# estado        ACREALAGOASAMAPÁAMAZONASBAHIACEARÁDISTRITO FED...
# tipo          Cédulas - 1a. famíliaCédulas - 1a. famíliaCédu...
# tipo2                                                       130
# quantidade                                                50539
# dtype: object
# ano                                                       98147
# estado        ACREACREALAGOASALAGOASAMAPÁAMAZONASBAHIABAHIAC...
# tipo          Cédulas - 1a. famíliaCédulas - em polímeroCédu...
# tipo2                                                       490
# ...

# %%
#2004
falsano2004 = fals [fals.ano == 2004]
falsano2004_1 = falsano2004 [falsano2004.tipo2 == 1]
falsano2004_5 = falsano2004 [falsano2004.tipo2 == 5]
falsano2004_10 = falsano2004 [falsano2004.tipo2 == 10]
falsano2004_20 = falsano2004 [falsano2004.tipo2 == 20]
falsano2004_50 = falsano2004 [falsano2004.tipo2 == 50]
falsano2004_100 = falsano2004 [falsano2004.tipo2 == 100]

print falsano2004_1.sum()
print falsano2004_5.sum()
print falsano2004_10.sum()
print falsano2004_20.sum()
print falsano2004_50.sum()
print falsano2004_100.sum()
# Out:
# ano                                                       36072
# estado        BAHIACEARÁDISTRITO FEDERALESPÍRITO SANTOGOIÁSM...
# tipo          Cédulas - 1a. famíliaCédulas - 1a. famíliaCédu...
# tipo2                                                        18
# quantidade                                                  172
# dtype: object
# ano                                                       56112
# estado        ACREALAGOASAMAPÁAMAZONASBAHIACEARÁDISTRITO FED...
# tipo          Cédulas - 1a. famíliaCédulas - 1a. famíliaCédu...
# tipo2                                                       140
# quantidade                                                29492
# dtype: object
# ano                                                      102204
# estado        ACREALAGOASAMAPÁAMAPÁAMAZONASAMAZONASBAHIABAHI...
# tipo          Cédulas - 1a. famíliaCédulas - 1a. famíliaCédu...
# tipo2                                                       510
# ...

# %%
#2005
falsano2005 = fals [fals.ano == 2005]
falsano2005_1 = falsano2005 [falsano2005.tipo2 == 1]
falsano2005_5 = falsano2005 [falsano2005.tipo2 == 5]
falsano2005_10 = falsano2005 [falsano2005.tipo2 == 10]
falsano2005_20 = falsano2005 [falsano2005.tipo2 == 20]
falsano2005_50 = falsano2005 [falsano2005.tipo2 == 50]
falsano2005_100 = falsano2005 [falsano2005.tipo2 == 100]

print falsano2005_1.sum()
print falsano2005_5.sum()
print falsano2005_10.sum()
print falsano2005_20.sum()
print falsano2005_50.sum()
print falsano2005_100.sum()
# Out:
# ano                                                       38095
# estado        AMAZONASBAHIADISTRITO FEDERALESPÍRITO SANTOGOI...
# tipo          Cédulas - 1a. famíliaCédulas - 1a. famíliaCédu...
# tipo2                                                        19
# quantidade                                                  237
# dtype: object
# ano                                                       56140
# estado        ACREALAGOASAMAPÁAMAZONASBAHIACEARÁDISTRITO FED...
# tipo          Cédulas - 1a. famíliaCédulas - 1a. famíliaCédu...
# tipo2                                                       140
# quantidade                                                31054
# dtype: object
# ano                                                      110275
# estado        ACREACREALAGOASALAGOASAMAPÁAMAZONASAMAZONASBAH...
# tipo          Cédulas - 1a. famíliaCédulas - em polímeroCédu...
# tipo2                                                       550
# ...

# %%
#2006
falsano2006 = fals [fals.ano == 2006]
falsano2006_1 = falsano2006 [falsano2006.tipo2 == 1]
falsano2006_5 = falsano2006 [falsano2006.tipo2 == 5]
falsano2006_10 = falsano2006 [falsano2006.tipo2 == 10]
falsano2006_20 = falsano2006 [falsano2006.tipo2 == 20]
falsano2006_50 = falsano2006 [falsano2006.tipo2 == 50]
falsano2006_100 = falsano2006 [falsano2006.tipo2 == 100]

print falsano2006_1.sum()
print falsano2006_2.sum()
print falsano2006_5.sum()
print falsano2006_10.sum()
print falsano2006_20.sum()
print falsano2006_50.sum()
print falsano2006_100.sum()
# Out:
# ano                                                       38114
# estado        ACREAMAZONASBAHIACEARÁDISTRITO FEDERALESPÍRITO...
# tipo          Cédulas - 1a. famíliaCédulas - 1a. famíliaCédu...
# tipo2                                                        19
# quantidade                                                  326
# dtype: object
# ano                                                       50150
# estado        ALAGOASAMAPÁAMAZONASBAHIACEARÁDISTRITO FEDERAL...
# tipo          Cédulas - 1a. famíliaCédulas - 1a. famíliaCédu...
# tipo2                                                        50
# quantidade                                                 1486
# dtype: object
# ano                                                       56168
# estado        ACREALAGOASAMAPÁAMAZONASBAHIACEARÁDISTRITO FED...
# tipo          Cédulas - 1a. famíliaCédulas - 1a. famíliaCédu...
# tipo2                                                       140
# ...

# %%
#2007
falsano2007 = fals [fals.ano == 2007]
falsano2007_1 = falsano2007 [falsano2007.tipo2 == 1]
falsano2007_5 = falsano2007 [falsano2007.tipo2 == 5]
falsano2007_10 = falsano2007 [falsano2007.tipo2 == 10]
falsano2007_20 = falsano2007 [falsano2007.tipo2 == 20]
falsano2007_50 = falsano2007 [falsano2007.tipo2 == 50]
falsano2007_100 = falsano2007 [falsano2007.tipo2 == 100]

print falsano2007_1.sum()
print falsano2007_5.sum()
print falsano2007_10.sum()
print falsano2007_20.sum()
print falsano2007_50.sum()
print falsano2007_100.sum()
# Out:
# ano                                                       30105
# estado        ALAGOASBAHIADISTRITO FEDERALGOIÁSMARANHÃOMATO ...
# tipo          Cédulas - 1a. famíliaCédulas - 1a. famíliaCédu...
# tipo2                                                        15
# quantidade                                                  218
# dtype: object
# ano                                                       56196
# estado        ACREALAGOASAMAPÁAMAZONASBAHIACEARÁDISTRITO FED...
# tipo          Cédulas - 1a. famíliaCédulas - 1a. famíliaCédu...
# tipo2                                                       140
# quantidade                                                29557
# dtype: object
# ano                                                      104364
# estado        ACREALAGOASALAGOASAMAPÁAMAZONASAMAZONASBAHIABA...
# tipo          Cédulas - 1a. famíliaCédulas - 1a. famíliaCédu...
# tipo2                                                       520
# ...

# %%
#2008
falsano2008 = fals [fals.ano == 2008]
falsano2008_1 = falsano2008 [falsano2008.tipo2 == 1]
falsano2008_5 = falsano2008 [falsano2008.tipo2 == 5]
falsano2008_10 = falsano2008 [falsano2008.tipo2 == 10]
falsano2008_20 = falsano2008 [falsano2008.tipo2 == 20]
falsano2008_50 = falsano2008 [falsano2008.tipo2 == 50]
falsano2008_100 = falsano2008 [falsano2008.tipo2 == 100]

print falsano2008_1.sum()
print falsano2008_5.sum()
print falsano2008_10.sum()
print falsano2008_20.sum()
print falsano2008_50.sum()
print falsano2008_100.sum()
# Out:
# ano                                                       24096
# estado        BAHIAGOIÁSMATO GROSSOMATO GROSSO DO SULMINAS G...
# tipo          Cédulas - 1a. famíliaCédulas - 1a. famíliaCédu...
# tipo2                                                        12
# quantidade                                                   63
# dtype: object
# ano                                                       54216
# estado        ACREALAGOASAMAPÁBAHIACEARÁDISTRITO FEDERALESPÍ...
# tipo          Cédulas - 1a. famíliaCédulas - 1a. famíliaCédu...
# tipo2                                                       135
# quantidade                                                23323
# dtype: object
# ano                                                      104416
# estado        ACREALAGOASALAGOASAMAPÁAMAZONASAMAZONASBAHIABA...
# tipo          Cédulas - 1a. famíliaCédulas - 1a. famíliaCédu...
# tipo2                                                       520
# ...

# %%
#2009
falsano2009 = fals [fals.ano == 2009]
falsano2009_1 = falsano2009 [falsano2009.tipo2 == 1]
falsano2009_5 = falsano2009 [falsano2009.tipo2 == 5]
falsano2009_10 = falsano2009 [falsano2009.tipo2 == 10]
falsano2009_20 = falsano2009 [falsano2009.tipo2 == 20]
falsano2009_50 = falsano2009 [falsano2009.tipo2 == 50]
falsano2009_100 = falsano2009 [falsano2009.tipo2 == 100]

print falsano2009_1.sum()
print falsano2009_5.sum()
print falsano2009_10.sum()
print falsano2009_20.sum()
print falsano2009_50.sum()
print falsano2009_100.sum()
# Out:
# ano                                                       20090
# estado        BAHIAMATO GROSSO DO SULMINAS GERAISPARAÍBAPARA...
# tipo          Cédulas - 1a. famíliaCédulas - 1a. famíliaCédu...
# tipo2                                                        10
# quantidade                                                   32
# dtype: object
# ano                                                       50225
# estado        ACREALAGOASAMAPÁAMAZONASBAHIACEARÁDISTRITO FED...
# tipo          Cédulas - 1a. famíliaCédulas - 1a. famíliaCédu...
# tipo2                                                       125
# quantidade                                                 6992
# dtype: object
# ano                                                      102459
# estado        ACREALAGOASALAGOASAMAPÁAMAZONASAMAZONASBAHIABA...
# tipo          Cédulas - 1a. famíliaCédulas - 1a. famíliaCédu...
# tipo2                                                       510
# ...

# %%
#2010
falsano2010 = fals [fals.ano == 2010]
falsano2010_1 = falsano2010 [falsano2010.tipo2 == 1]
falsano2010_5 = falsano2010 [falsano2010.tipo2 == 5]
falsano2010_10 = falsano2010 [falsano2010.tipo2 == 10]
falsano2010_20 = falsano2010 [falsano2010.tipo2 == 20]
falsano2010_50 = falsano2010 [falsano2010.tipo2 == 50]
falsano2010_100 = falsano2010 [falsano2010.tipo2 == 100]

print falsano2010_1.sum()
print falsano2010_5.sum()
print falsano2010_10.sum()
print falsano2010_20.sum()
print falsano2010_50.sum()
print falsano2010_100.sum()
# Out:
# ano                                                       10050
# estado        DISTRITO FEDERALESPÍRITO SANTOPARANÁRIO GRANDE...
# tipo          Cédulas - 1a. famíliaCédulas - 1a. famíliaCédu...
# tipo2                                                         5
# quantidade                                                    6
# dtype: object
# ano                                                       52260
# estado        ACREALAGOASAMAPÁAMAZONASBAHIACEARÁDISTRITO FED...
# tipo          Cédulas - 1a. famíliaCédulas - 1a. famíliaCédu...
# tipo2                                                       130
# quantidade                                                14421
# dtype: object
# ano                                                      100500
# estado        ACREALAGOASALAGOASAMAPÁAMAZONASAMAZONASBAHIABA...
# tipo          Cédulas - 1a. famíliaCédulas - 1a. famíliaCédu...
# tipo2                                                       500
# ...

# %%
#2011
falsano2011 = fals [fals.ano == 2011]
falsano2011_1 = falsano2011 [falsano2011.tipo2 == 1]
falsano2011_5 = falsano2011 [falsano2011.tipo2 == 5]
falsano2011_10 = falsano2011 [falsano2011.tipo2 == 10]
falsano2011_20 = falsano2011 [falsano2011.tipo2 == 20]
falsano2011_50 = falsano2011 [falsano2011.tipo2 == 50]
falsano2011_100 = falsano2011 [falsano2011.tipo2 == 100]

print falsano2011_1.sum()
print falsano2011_5.sum()
print falsano2011_10.sum()
print falsano2011_20.sum()
print falsano2011_50.sum()
print falsano2011_100.sum()
# Out:
# ano                                                        6033
# estado                                PARANÁPERNAMBUCOSÃO PAULO
# tipo          Cédulas - 1a. famíliaCédulas - 1a. famíliaCédu...
# tipo2                                                         3
# quantidade                                                    8
# dtype: object
# ano                                                       52286
# estado        ACREALAGOASAMAPÁAMAZONASBAHIACEARÁDISTRITO FED...
# tipo          Cédulas - 1a. famíliaCédulas - 1a. famíliaCédu...
# tipo2                                                       130
# quantidade                                                11023
# dtype: object
# ano                                                       92506
# estado        ACREALAGOASALAGOASAMAPÁAMAZONASAMAZONASBAHIABA...
# tipo          Cédulas - 1a. famíliaCédulas - 1a. famíliaCédu...
# tipo2                                                       460
# ...

# %%
#2012
falsano2012 = fals [fals.ano == 2012]
falsano2012_1 = falsano2012 [falsano2012.tipo2 == 1]
falsano2012_5 = falsano2012 [falsano2012.tipo2 == 5]
falsano2012_10 = falsano2012 [falsano2012.tipo2 == 10]
falsano2012_20 = falsano2012 [falsano2012.tipo2 == 20]
falsano2012_50 = falsano2012 [falsano2012.tipo2 == 50]
falsano2012_100 = falsano2012 [falsano2012.tipo2 == 100]

print falsano2012_1.sum()
print falsano2012_5.sum()
print falsano2012_10.sum()
print falsano2012_20.sum()
print falsano2012_50.sum()
print falsano2012_100.sum()
# Out:
# ano                                                       10060
# estado        MINAS GERAISRIO DE JANEIRORIO GRANDE DO NORTER...
# tipo          Cédulas - 1a. famíliaCédulas - 1a. famíliaCédu...
# tipo2                                                         5
# quantidade                                                    8
# dtype: object
# ano                                                       54324
# estado        ACREALAGOASAMAPÁAMAZONASBAHIACEARÁDISTRITO FED...
# tipo          Cédulas - 1a. famíliaCédulas - 1a. famíliaCédu...
# tipo2                                                       135
# quantidade                                                 5024
# dtype: object
# ano                                                      124744
# estado        ACREALAGOASALAGOASAMAPÁAMAZONASAMAZONASAMAZONA...
# tipo          Cédulas - 1a. famíliaCédulas - 1a. famíliaCédu...
# tipo2                                                       620
# ...

# %%
#2013
falsano2013 = fals [fals.ano == 2013]
falsano2013_1 = falsano2013 [falsano2013.tipo2 == 1]
falsano2013_5 = falsano2013 [falsano2013.tipo2 == 5]
falsano2013_10 = falsano2013 [falsano2013.tipo2 == 10]
falsano2013_20 = falsano2013 [falsano2013.tipo2 == 20]
falsano2013_50 = falsano2013 [falsano2013.tipo2 == 50]
falsano2013_100 = falsano2013 [falsano2013.tipo2 == 100]

print falsano2013_1.sum()
print falsano2013_5.sum()
print falsano2013_10.sum()
print falsano2013_20.sum()
print falsano2013_50.sum()
print falsano2013_100.sum()
# Out:
# ano                            2013
# estado             DISTRITO FEDERAL
# tipo          Cédulas - 1a. família
# tipo2                             1
# quantidade                       22
# dtype: object
# ano                                                       80520
# estado        ACREALAGOASAMAPÁAMAZONASBAHIABAHIACEARÁDISTRIT...
# tipo          Cédulas - 1a. famíliaCédulas - 1a. famíliaCédu...
# tipo2                                                       200
# quantidade                                                 4515
# dtype: object
# ano                                                      132858
# estado        ACREACREALAGOASALAGOASALAGOASAMAPÁAMAPÁAMAZONA...
# tipo          Cédulas - 1a. famíliaCédulas - 2a. famíliaCédu...
# tipo2                                                       660
# quantidade                                                20917
# dtype: object
# ano                                                       96624
# ...

# %%
#2014
falsano2014 = fals [fals.ano == 2014]
falsano2014_1 = falsano2014 [falsano2014.tipo2 == 1]
falsano2014_5 = falsano2014 [falsano2014.tipo2 == 5]
falsano2014_10 = falsano2014 [falsano2014.tipo2 == 10]
falsano2014_20 = falsano2014 [falsano2014.tipo2 == 20]
falsano2014_50 = falsano2014 [falsano2014.tipo2 == 50]
falsano2014_100 = falsano2014 [falsano2014.tipo2 == 100]

print falsano2014_1.sum()
print falsano2014_5.sum()
print falsano2014_10.sum()
print falsano2014_20.sum()
print falsano2014_50.sum()
print falsano2014_100.sum()
# Out:
# ano                            2014
# estado                       PARANÁ
# tipo          Cédulas - 1a. família
# tipo2                             1
# quantidade                        1
# dtype: object
# ano                                                      102714
# estado        ACREALAGOASALAGOASAMAPÁAMAPÁAMAZONASAMAZONASBA...
# tipo          Cédulas - 1a. famíliaCédulas - 1a. famíliaCédu...
# tipo2                                                       255
# quantidade                                                 9314
# dtype: object
# ano                                                      132924
# estado        ACREACREALAGOASALAGOASAMAPÁAMAZONASAMAZONASBAH...
# tipo          Cédulas - 1a. famíliaCédulas - 2a. famíliaCédu...
# tipo2                                                       660
# quantidade                                                18250
# dtype: object
# ano                                                       96672
# ...

# %%
#2015
falsano2015 = fals [fals.ano == 2015]
falsano2015_1 = falsano2015 [falsano2015.tipo2 == 1]
falsano2015_5 = falsano2015 [falsano2015.tipo2 == 5]
falsano2015_10 = falsano2015 [falsano2015.tipo2 == 10]
falsano2015_20 = falsano2015 [falsano2015.tipo2 == 20]
falsano2015_50 = falsano2015 [falsano2015.tipo2 == 50]
falsano2015_100 = falsano2015 [falsano2015.tipo2 == 100]

print falsano2015_1.sum()
print falsano2015_5.sum()
print falsano2015_10.sum()
print falsano2015_20.sum()
print falsano2015_50.sum()
print falsano2015_100.sum()
# Out:
# ano                            2015
# estado          RIO GRANDE DO NORTE
# tipo          Cédulas - 1a. família
# tipo2                             1
# quantidade                        1
# dtype: object
# ano                                                      102765
# estado        ACREALAGOASALAGOASAMAPÁAMAPÁAMAZONASAMAZONASBA...
# tipo          Cédulas - 1a. famíliaCédulas - 1a. famíliaCédu...
# tipo2                                                       255
# quantidade                                                 7039
# dtype: object
# ano                                                      120900
# estado        ACREACREALAGOASALAGOASAMAPÁAMAZONASAMAZONASBAH...
# tipo          Cédulas - 1a. famíliaCédulas - 2a. famíliaCédu...
# tipo2                                                       600
# quantidade                                                14649
# dtype: object
# ano                                                      104780
# ...

# %%
#2016
falsano2016 = fals [fals.ano == 2016]
falsano2016_1 = falsano2016 [falsano2016.tipo2 == 1]
falsano2016_5 = falsano2016 [falsano2016.tipo2 == 5]
falsano2016_10 = falsano2016 [falsano2016.tipo2 == 10]
falsano2016_20 = falsano2016 [falsano2016.tipo2 == 20]
falsano2016_50 = falsano2016 [falsano2016.tipo2 == 50]
falsano2016_100 = falsano2016 [falsano2016.tipo2 == 100]

print falsano2016_1.sum()
print falsano2016_5.sum()
print falsano2016_10.sum()
print falsano2016_20.sum()
print falsano2016_50.sum()
print falsano2016_100.sum()
# Out:
# ano           0.0
# estado        0.0
# tipo          0.0
# tipo2         0.0
# quantidade    0.0
# dtype: float64
# ano                                                      102816
# estado        ACREALAGOASALAGOASAMAPÁAMAPÁAMAZONASAMAZONASBA...
# tipo          Cédulas - 1a. famíliaCédulas - 1a. famíliaCédu...
# tipo2                                                       255
# quantidade                                                 8242
# dtype: object
# ano                                                      122976
# estado        ACREACREALAGOASALAGOASALAGOASAMAPÁAMAZONASAMAZ...
# tipo          Cédulas - 1a. famíliaCédulas - 2a. famíliaCédu...
# tipo2                                                       610
# quantidade                                                14256
# dtype: object
# ano                                                      106848
# estado        ACREACREALAGOASALAGOASAMAPÁAMAZONASAMAZONASBAH...
# ...

# %%
#2017
falsano2017 = fals [fals.ano == 2017]
falsano2017_1 = falsano2017 [falsano2017.tipo2 == 1]
falsano2017_5 = falsano2017 [falsano2017.tipo2 == 5]
falsano2017_10 = falsano2017 [falsano2017.tipo2 == 10]
falsano2017_20 = falsano2017 [falsano2017.tipo2 == 20]
falsano2017_50 = falsano2017 [falsano2017.tipo2 == 50]
falsano2017_100 = falsano2017 [falsano2017.tipo2 == 100]

print falsano2017_1.sum()
print falsano2017_5.sum()
print falsano2017_10.sum()
print falsano2017_20.sum()
print falsano2017_50.sum()
print falsano2017_100.sum()
# Out:
# ano           0.0
# estado        0.0
# tipo          0.0
# tipo2         0.0
# quantidade    0.0
# dtype: float64
# ano                                                      100850
# estado        ALAGOASALAGOASAMAPÁAMAPÁAMAZONASAMAZONASBAHIAB...
# tipo          Cédulas - 1a. famíliaCédulas - 2a. famíliaCédu...
# tipo2                                                       250
# quantidade                                                 3837
# dtype: object
# ano                                                      104884
# estado        ALAGOASALAGOASAMAPÁAMAPÁAMAZONASAMAZONASBAHIAB...
# tipo          Cédulas - 1a. famíliaCédulas - 2a. famíliaCédu...
# tipo2                                                       520
# quantidade                                                 8991
# dtype: object
# ano                                                       98833
# estado        ACREALAGOASALAGOASAMAPÁAMAZONASAMAZONASBAHIABA...
# ...

# %%
#Notas de 2 - havia me esquecido, elenquei todas aqui.

falsano1998_2 = falsano1998 [falsano1998.tipo2 == 2]
falsano1999_2 = falsano1999 [falsano1999.tipo2 == 2]
falsano2000_2 = falsano2000 [falsano2000.tipo2 == 2]
falsano2001_2 = falsano2001 [falsano2001.tipo2 == 2]
falsano2002_2 = falsano2002 [falsano2002.tipo2 == 2]
falsano2003_2 = falsano2003 [falsano2003.tipo2 == 2]
falsano2004_2 = falsano2004 [falsano2004.tipo2 == 2]
falsano2005_2 = falsano2005 [falsano2005.tipo2 == 2]
falsano2006_2 = falsano2006 [falsano2006.tipo2 == 2]
falsano2007_2 = falsano2007 [falsano2007.tipo2 == 2]
falsano2008_2 = falsano2008 [falsano2008.tipo2 == 2]
falsano2009_2 = falsano2009 [falsano2009.tipo2 == 2]
falsano2010_2 = falsano2010 [falsano2010.tipo2 == 2]
falsano2011_2 = falsano2011 [falsano2011.tipo2 == 2]
falsano2012_2 = falsano2012 [falsano2012.tipo2 == 2]
falsano2013_2 = falsano2013 [falsano2013.tipo2 == 2]
falsano2014_2 = falsano2014 [falsano2014.tipo2 == 2]
falsano2015_2 = falsano2015 [falsano2015.tipo2 == 2]
falsano2016_2 = falsano2016 [falsano2016.tipo2 == 2]
falsano2017_2 = falsano2017 [falsano2017.tipo2 == 2]

print falsano1998_2.sum()
print falsano1999_2.sum()
print falsano2000_2.sum()
print falsano2001_2.sum()
print falsano2002_2.sum()
print falsano2003_2.sum()
print falsano2004_2.sum()
print falsano2005_2.sum()
print falsano2006_2.sum()
print falsano2007_2.sum()
print falsano2008_2.sum()
print falsano2009_2.sum()
print falsano2010_2.sum()
print falsano2011_2.sum()
print falsano2012_2.sum()
print falsano2013_2.sum()
print falsano2014_2.sum()
print falsano2015_2.sum()
print falsano2016_2.sum()
print falsano2017_2.sum()
# Out:
# ano           0.0
# estado        0.0
# tipo          0.0
# tipo2         0.0
# quantidade    0.0
# dtype: float64
# ano           0.0
# estado        0.0
# tipo          0.0
# tipo2         0.0
# quantidade    0.0
# dtype: float64
# ano           0.0
# estado        0.0
# tipo          0.0
# tipo2         0.0
# quantidade    0.0
# dtype: float64
# ano           0.0
# estado        0.0
# tipo          0.0
# tipo2         0.0
# quantidade    0.0
# dtype: float64
# ano                                                       38038
# estado        AMAZONASBAHIACEARÁDISTRITO FEDERALGOIÁSMARANHÃ...
# tipo          Cédulas - 1a. famíliaCédulas - 1a. famíliaCédu...
# tipo2                                                        38
# quantidade                                                  722
# dtype: object
# ano                                                       40060
# estado        AMAZONASBAHIACEARÁDISTRITO FEDERALESPÍRITO SAN...
# ...

# %%
fals.estado.value_counts()
# Out:
# SÃO PAULO              174
# PARANÁ                 173
# RIO DE JANEIRO         171
# MINAS GERAIS           169
# BAHIA                  168
# RIO GRANDE DO SUL      168
# PERNAMBUCO             167
# GOIÁS                  165
# CEARÁ                  165
# DISTRITO FEDERAL       164
# ESPÍRITO SANTO         161
# AMAZONAS               160
# SERGIPE                158
# PARÁ                   157
# MARANHÃO               156
# MATO GROSSO DO SUL     155
# MATO GROSSO            154
# SANTA CATARINA         154
# PARAÍBA                153
# RIO GRANDE DO NORTE    152
# ALAGOAS                151
# RONDÔNIA               149
# PIAUÍ                  147
# TOCANTINS              143
# AMAPÁ                  119
# ACRE                   117
# RORAIMA                110
# NAO INFORMADO           37
# Name: estado, dtype: int64

# %%
falssp = fals [fals.estado == 'SÃO PAULO']
falsspq = falssp.quantidade
print 'São Paulo'
print falsspq.sum()

falspr = fals [fals.estado == 'PARANÁ']
falsprq = falspr.quantidade
print 'Paraná'
print falsprq.sum()

falsrj = fals [fals.estado == 'RIO DE JANEIRO']
falsrjq = falsrj.quantidade
print 'Rio de Janeiro'
print falsrjq.sum()

falsmg = fals [fals.estado == 'MINAS GERAIS']
falsmgq = falsmg.quantidade
print 'Minas Gerais'
print falsmgq.sum()

falsba = fals [fals.estado == 'BAHIA']
falsbaq = falsba.quantidade
print 'Bahia'
print falsbaq.sum()

falsrs = fals [fals.estado == 'RIO GRANDE DO SUL']
falsrsq = falsrs.quantidade
print 'Rio Grande do Sul'
print falsrsq.sum()

falspe = fals [fals.estado == 'PERNAMBUCO']
falspeq = falspe.quantidade
print 'Pernambuco'
print falspeq.sum()

falsgo = fals [fals.estado == 'GOIÁS']
falsgoq = falsgo.quantidade
print 'Goiás'
print falsgoq.sum()

falsce = fals [fals.estado == 'CEARÁ']
falsceq = falsce.quantidade
print 'Ceará'
print falsceq.sum()

falsdf = fals [fals.estado == 'DISTRITO FEDERAL']
falsdfq = falsdf.quantidade
print 'Distrito Federal'
print falsdfq.sum()

falses = fals [fals.estado == 'ESPÍRITO SANTO']
falsesq = falses.quantidade
print 'Espírito Santo'
print falsesq.sum()

falsam = fals [fals.estado == 'AMAZONAS']
falsamq = falsam.quantidade
print 'Amazonas'
print falsamq.sum()

falsse = fals [fals.estado == 'SERGIPE']
falsseq = falsse.quantidade
print 'Sergipe'
print falsseq.sum()

falspa = fals [fals.estado == 'PARÁ']
falspaq = falspa.quantidade
print 'Pará'
print falspaq.sum()

falsma = fals [fals.estado == 'MARANHÃO']
falsmaq = falsma.quantidade
print 'Maranhão'
print falsmaq.sum()

falsms = fals [fals.estado == 'MATO GROSSO DO SUL']
falsmsq = falsms.quantidade
print 'Mato Grosso do Sul'
print falsmsq.sum()

falsmt = fals [fals.estado == 'MATO GROSSO']
falsmtq = falsmt.quantidade
print 'Mato Grosso'
print falsmtq.sum()

falssc = fals [fals.estado == 'SANTA CATARINA']
falsscq = falssc.quantidade
print 'Santa Catarina'
print falsscq.sum()

falspb = fals [fals.estado == 'PARAÍBA']
falspbq = falspb.quantidade
print 'Paraíba'
print falspbq.sum()

falsrn = fals [fals.estado == 'RIO GRANDE DO NORTE']
falsrnq = falsrn.quantidade
print 'Rio Grande do Norte'
print falsrnq.sum()

falsal = fals [fals.estado == 'ALAGOAS']
falsalq = falsal.quantidade
print 'Alagoas'
print falsalq.sum()

falsro = fals [fals.estado == 'RONDÔNIA']
falsroq = falsro.quantidade
print 'Rondônia'
print falsroq.sum()

falspi = fals [fals.estado == 'PIAUÍ']
falspiq = falspi.quantidade
print 'Piauí'
print falspiq.sum()

falsto = fals [fals.estado == 'TOCANTINS']
falstoq = falsto.quantidade
print 'Tocantins'
print falstoq.sum()

falsap = fals [fals.estado == 'AMAPÁ']
falsapq = falsap.quantidade
print 'Amapá'
print falsapq.sum()

falsac = fals [fals.estado == 'ACRE']
falsacq = falsac.quantidade
print 'Acre'
print falsacq.sum()

falsrr = fals [fals.estado == 'RORAIMA']
falsrrq = falsrr.quantidade
print 'Roraima'
print falsrrq.sum()

falsni = fals [fals.estado == 'NAO INFORMADO']
falsniq = falsni.quantidade
print 'Não informado'
print falsspq.sum()
# Out:
# São Paulo
# 2932918
# Paraná
# 504187
# Rio de Janeiro
# 845435
# Minas Gerais
# 745256
# Bahia
# 358865
# Rio Grande do Sul
# 492315
# Pernambuco
# 248408
# Goiás
# 338531
# Ceará
# 178525
# Distrito Federal
# 219363
# Espírito Santo
# 90472
# Amazonas
# 44218
# Sergipe
# 54417
# Pará
# 92344
# Maranhão
# 79385
# Mato Grosso do Sul
# 158000
# Mato Grosso
# 67341
# Santa Catarina
# 239077
# Paraíba
# 54597
# Rio Grande do Norte
# 50665
# Alagoas
# 52816
# Rondônia
# 39379
# Piauí
# 51652
# Tocantins
# 31101
# Amapá
# 6456
# Acre
# 6544
# Roraima
# 3107
# Não informado
# 2932918

# %%
falssegunda = fals [fals.tipo == 'Cédulas - 2a. família']
falssegundaq = falssegunda.quantidade
print 'Segunda família'
print falssegundaq.sum()

falsprimeira = fals [fals.tipo == 'Cédulas - 1a. família']
falsprimeiraq = falsprimeira.quantidade
print 'Primeira família'
print falsprimeiraq.sum()
#falsseg = fals.tipo
#falsseg.value_counts()
# Out:
# Segunda família
# 1270963
# Primeira família
# 6574476

# %%
falsdf = fals [fals.estado == 'DISTRITO FEDERAL']

falsdf1998 = falsdf [falsdf.ano == 1998]
falsdf1999 = falsdf [falsdf.ano == 1999]
falsdf2000 = falsdf [falsdf.ano == 2000]
falsdf2001 = falsdf [falsdf.ano == 2001]
falsdf2002 = falsdf [falsdf.ano == 2002]
falsdf2003 = falsdf [falsdf.ano == 2003]
falsdf2004 = falsdf [falsdf.ano == 2004]
falsdf2005 = falsdf [falsdf.ano == 2005]
falsdf2006 = falsdf [falsdf.ano == 2006]
falsdf2007 = falsdf [falsdf.ano == 2007]
falsdf2008 = falsdf [falsdf.ano == 2008]
falsdf2009 = falsdf [falsdf.ano == 2009]
falsdf2010 = falsdf [falsdf.ano == 2010]
falsdf2011 = falsdf [falsdf.ano == 2011]

#falsdf.ano.value_counts()



#falsdf.tipo2.value_counts()
#falsdf1 = falsdf [falsdf.tipo2 == 1]
#falsdf.tipo2.value_counts()
